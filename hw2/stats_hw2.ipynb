# %% [markdown]
# ## Pen and paper ex.1

# %% [markdown]
# **a)**
# $\mathbb{V}(X) = \mathbb{E}(X^2) - \mu^2$
#
# $\mathbb{V}(X) = \mathbb{E}((X - \mu)^2) = \mathbb{E}(X^2 - 2 \mu X + \mu ^ 2) = \mathbb{E}(X^ 2) - \underset{= 2 \mu^2} {2 \mu \mathbb{E}(X)} + \mu ^ 2 = \mathbb{E}(X^2) - \mu^2$
#
# **b)**
# $\mathbb{V}(a X + b) = a^2 \mathbb{V},\quad a,b \in \mathbb{R}$
#
# $\mathbb{V}(a X + b) = \mathbb{E}((a X + b - a \mu - b)^2) = \mathbb{E}((a X - a \mu) ^ 2) = \mathbb{E}(a^2(X - \mu) ^ 2) = a ^ 2 \mathbb{E}((X - \mu) ^ 2) = a^2 V(X)$

# %% [markdown]
# ## Pen and paper ex.2

# %% [markdown]
# $X \sim Uniform(a, b),\quad \mathbb{E}(X)-?, \mathbb{V}(X)-?$
#
# $X = \left\{
# \begin{array}{l}
# \frac{1}{b - a},\quad x \in [a, b] \\
# 0,\quad x \notin [a, b]
# \end{array}
# \right.$
#
# <br>
# <br>
#
#
# $\mathbb{E}(X) = \int_a^b x \frac{1}{b - a}\,dx = \frac{x^2}{2(b-a)}|_{a}^{b} = \frac{b^2}{2 (b - a)} - \frac{a^2}{2 (b - a)} = \frac{a + b}{2}$
#
# <br>
# <br>
#
# $\mathbb{V}(X) = \mathbb{E}(X^2) - \underset{=(\frac{a+b}{2})^2}{\mu^2} = \int_a^b x^2 \frac{1}{b - a}\,dx - (\frac{a+b}{2})^2 = \frac{x^3}{3(b-a)}|_{a}^{b} - (\frac{a+b}{2})^2 = \frac{b^3}{3(b - a)} - \frac{a^3}{3(b - a)} - (\frac{a + b}{2})^2 = $
#
# $= \frac{(b - a)(a^2 + ab + b^2)}{3(b-a)} - \frac{(a + b)^2}{4} = \frac{a^2 + ab + b^2}{3} - \frac{b^2 + 2ab + a^2}{4} = \frac{4 a^2 + 4 ab + 4 b^2 - 3b^2 - 6 ab -3 a^2}{12} = \frac{a^2 + b^2 - 2 ab}{12} = \frac{(b - a)^2}{12}$

# %% [markdown]
# ## Pen and paper ex.3

# %% [markdown]
# $X, Y \sim Uniform(a, b)$
#
# $Z = max\{X, Y\},\quad \mathbb{E}(Z)-?, \mathbb{V}(Z)-?$
#
# $max\{X, Y\} = \left\{
# \begin{array}{l}
# x,\quad x \ge y \\
# y,\quad y > x
# \end{array}
# \right.$
#
# <br>
# <br>
#
# $\mathbb{E}(Z) = \int z\cdot f_Z(z)\, dz = \int \int_{x<y} y \, dx dy + \int \int_{x \ge y} x \, dx dy = \int_0^y \int_0^1 y \, dx dy + \int_0^x \int_0^1 x \, dx dy = \int_0^1 y^2 dy + \int_0^1 x^2 dx = \frac{1}{3} + \frac{1}{3} = \frac{2}{3}$
#
# <br>
# <br>
#
# $\mathbb{V}(Z) = \int z^2\cdot f_Z(z)\, dz - \mathbb{E^2}(Z)= \int \int_{x<y} y^2 \, dx dy + \int \int_{x^2 \ge y} x \, dx dy - \mathbb{E^2}(Z) = $
#
# $= \int_0^y \int_0^1 y^2 \, dx dy + \int_0^x \int_0^1 x^2 \, dx dy - \frac{4}{9}= \int_0^1 y^3 dy + \int_0^1 x^3 dx - \frac{4}{9}= \frac{2}{4} - \frac{4}{9} = \frac{18 - 16}{36} = \frac{1}{18}$

# %% [markdown]
# ## Pen and paper ex.4

# %% [markdown]
# | $f_{X,Y}(X,Y)$| y=-1 | y=0 | y=1 |
# |:------:|:--:|:--:|:--:|
# | x=-1 | 0 | 0.5 | 0 |
# | x=1 | 0.25 | 0 | 0.25 |

# %% [markdown]
# **a)**
#
# $Cov(X,Y) = \mathbb{E}(X \cdot Y) - \mathbb{E}(X)\mathbb{E}(Y)$
#
# $\mathbb{E}(X \cdot Y) = \int \int x \cdot y \cdot f_{X,Y}(x, y)\, dx dy = \sum_{x\in\{-1, 1\}}x\sum_{y\in\{-1, 0, 1\}}y f_{X,Y}(x, y) = $
#
# $= -1 \cdot (-1 \cdot 0 + 0 \cdot 0.5 + 1 \cdot 0) + 1 \cdot (-1 \cdot 0.25 + 0 \cdot 0 + 1 \cdot 0.25) = -1 \cdot 0.25 + 1 \cdot 0.25 = 0$
#
# $\mathbb{E}(X) = \int x \cdot f_X(x) = \sum_{x\in\{-1, 1\}} x \cdot f_X(x)\,$, where $f_X(x) = \int f_{X, Y}(x, y)\,dy$
#
# $\mathbb{E}(X) = -1 \cdot 0.5 + 1 \cdot 0.5 = 0$
#
# <br>
# <br>
#
# $Cov(X,Y) = 0 - 0 \cdot \mathbb{E}(Y) = 0$
#
# Also, $\rho = 0$, as $\rho = \frac{Cov(X, Y)}{\sigma_X \cdot \sigma_Y}$
#
# <br>
# <br>
#
# **b)**
#
# $X$ and $Y$ are not independent as they do not satisfy this equasion for all $x$ and $y$:
# $f_{XY}(X, Y) = f_X(X) \cdot f_Y(Y)$
#
# For example $x=-1$ and $y=-1$
#
# $f_{X, Y}(x=-1, y=-1) = 0$
#
# $f_{X}(x=-1) = 0.5$
#
# $f_{Y}(y=-1) = 0.25$
#
# So, $f_{X, Y}(x=-1, y=-1) \neq f_{X}(x=-1) \cdot f_{Y}(y=-1)$

# %% [markdown]
# If $X$ and $Y$ are independent therefore $\rho = 0$. But the converse is not correct in general!

# %% [markdown]
# ## Pen and paper ex.5

# %% [markdown]
# $f_{X,Y}(x, y) = \left\{
# \begin{array}{l}
# \frac{1}{3} (x + y),\quad 0\le x \le 1, \quad 0\le y \le 2, \\
# 0,\quad otherwise
# \end{array}
# \right.$
#
# $V(2X - 3Y + 8) = ?$

# %% [markdown]
# As $V(\sum_i a_i X_i) = \sum_i a^2_i V(X_i) + 2 \sum \sum_{i < j} a_i a_j Cov(X_i, X_j)$:
#
# $V(2X - 3Y + 8) = 4 V(X) + 9 V(Y) + 0 - 2 \cdot 6 \cdot Cov(X, Y) = 4 V(X) + 9 V(Y) - 12 \cdot Cov(X, Y)$
#
# Also,
#
# $Cov(X, Y) = \mathbb{E}(X \cdot Y) - \mathbb{E}(X)\cdot \mathbb{E}(Y)$
#
# <br>
#
# $\underline{\mathbb{E}(X \cdot Y)} = \int_0^1 \int_0^2 x \cdot y \frac{1}{3} (x + y)\, dx dy = \int_0^1 \int_0^2 \frac{1}{3} (x^2 y + x y^2)\, dx dy = \frac{1}{3} \int_0^1 dx (\frac{x^2 y^2}{2} + {x y ^ 3}{3}) |^2_0 = \frac{1}{3} \int_0^1 (2 x^2 + \frac{8}{3} x) dx = \frac{1}{3}(\frac{2 x ^3}{3} + \frac{x^2 8}{3 \cdot 2})|_0^1 = \frac{1}{3}(\frac{2}{3} + \frac{8}{6}) =$
# $= \frac{1}{3}(\frac{2}{3}+\frac{4}{3}) = \underline{\frac{2}{3}}$
#
# <br>
#
# $f_X(x) = \int_0^2 \frac{1}{3} (x + y)\, dy = \frac{1}{3} (x y + \frac{y^2}{2})|_0^2 = \frac{1}{3} (2 x + 2) = \frac{2}{3} (x + 1)$
#
# $\underline{\mathbb{E}(X)} = \int x f_X(x)\, dx = \frac{2}{3} \int_0^1 x (x + 1)\, dx = \frac{2}{3} (\frac{x ^ 3}{3} + \frac{x^2}{2})|_0^1 = \frac{2}{3} (\frac{1}{3} + \frac{1}{2}) = \frac{2}{3} (\frac{2}{6} + \frac{3}{6}) = \frac{2}{3} \frac{5}{6} = \underline{\frac{5}{9}}$
#
# <br>
#
# $f_Y(y) = \int_0^1 \frac{1}{3} (x + y)\, dx = \frac{1}{3} (y + \frac{1}{2})$
#
# $\underline{\mathbb{E}(Y)} = \int y f_Y(y)\, dy = \frac{1}{3} \int_0^2 (y^2 + \frac{y}{2})\, dy = \frac{1}{3} (\frac{y ^ 3}{3} + \frac{y^2}{4})|_0^2 = \frac{1}{3} (\frac{8}{3} + 1) = \underline{\frac{11}{9}}$
#
# <br>
#
# As $V(X) = \mathbb{E}(X^2) - \mathbb{E^2}(X)$, we need to find $\mathbb{E}(X^2)$:
#
# $\underline{\mathbb{E}(X^2)} = \int x^2 \cdot f_X(x)\, dx = \frac{2}{3} \int_0^1 x^2 (x + 1) dx = \frac{2}{3} (\frac{x^4}{4} + \frac{x^3}{3}) |^1_0 = \frac{2}{3} (\frac{1}{4} + \frac{1}{3}) = \frac{2}{3} (\frac{3+4}{12}) = \underline{\frac{7}{18}}$
#
# <br>
#
# The same for $V(Y) = \mathbb{E}(Y^2) - \mathbb{E^2}(Y)$, we need to find $\mathbb{E}(Y^2)$:
#
# $\underline{\mathbb{E}(Y^2)} = \int y^2 \cdot f_Y(y)\, dy = \frac{1}{3} \int_0^2 y^2 (y + \frac{1}{2}) dy = \frac{1}{3} (\frac{y^4}{4} + \frac{y^3}{3 \cdot 2}) |^2_0 = \frac{1}{3} (\frac{16}{4} + \frac{8}{6}) = \frac{1}{3} (\frac{48}{12} + \frac{16}{12}) = \frac{64}{12 \cdot 3} = \frac{32}{6 \cdot 3} = \underline{\frac{16}{9}}$
#
# <br>
#
# $V(2X - 3Y + 8) =  4 (\mathbb{E}(X^2) - \mathbb{E^2}(X)) + 9 (\mathbb{E}(Y^2) - \mathbb{E^2}(Y)) - 12 \cdot (\mathbb{E}(X \cdot Y) - \mathbb{E}(X)\cdot \mathbb{E}(Y)) = $
#
# $= \underset{\text{(1)}}{4 (\frac{7}{18} - (\frac{5}{9})^2)} + \underset{\text{(2)}}{9 (\frac{16}{9} - (\frac{11}{9})^2)} - \underset{\text{(3)}}{12 (\frac{2}{3} - \frac{5}{9} \cdot \frac{11}{9})} $

# %%
from fractions import Fraction
print('1) term: %s' % (4 * (Fraction(7, 18) - (Fraction(5, 9)) ** 2)))
print('2) term: %s' % (9 * (Fraction(16, 9) - (Fraction(11, 9)) ** 2)))
print('3) term: %s' % (12 * (Fraction(2, 3) - (Fraction(5, 9) * Fraction(11, 9) ))))
# Out:
# 1) term: 26/81
# 2) term: 23/9
# 3) term: -4/27

# %%
print('V... output: %s' % ((Fraction(26, 81) + Fraction(23, 9) - (-Fraction(4, 27) ))))
# Out:
# V... output: 245/81

# %% [markdown]
# So,
#
# $\underline{V(2X - 3Y + 8)} = = \underset{(1): \frac{26}{81}}{4 (\frac{7}{18} - (\frac{5}{9})^2)} + \underset{(2): \frac{23}{9}}{9 (\frac{16}{9} - (\frac{11}{9})^2)} - \underset{(3): \frac{-4}{27}}{12 (\frac{2}{3} - \frac{5}{9} \cdot \frac{11}{9})} = \underline{\frac{245}{81}}$

# %% [markdown]
# ## Programming ex. 1

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
#i.)
## IMPORT DATA FROM Input.txt
inputdata = np.loadtxt('./data/input/Input.txt')
#print(inputdata)
inputdata = [int(item) for item in inputdata]

## SET RANDOM SEED
np.random.seed(inputdata[0])

# %%
N = np.array(inputdata[1:])
lam = 1
k = 10

# %%
#calculate mean and var
mean = np.zeros((len(N), k))
var = np.zeros((len(N)))
for j in range(len(N)):
    for i in range(k):
        mean[j, i] = np.random.poisson(lam=1.0, size=N[j]).mean()
    #we consider sample variance here where the sample consists of a set of mean(X_n)
    var[j] = mean[j].var(ddof=1)

# %%
#write into the file
with open('./data/output/MeanVar.txt', 'w') as f:
    for j in range(len(N)):
        line = ','.join(['%1.2f' % item for item in mean[j]]) + '\n'
        f.write(line)
    line = ','.join(['%1.2f' % var[i] if i < len(N) else 'nan' for i in range(k)]) + '\n'
    f.write(line)

# %% [markdown]
# ## a)

# %%
plt.title('means')
plt.plot(np.repeat(N, k), mean.ravel(), '.')
plt.ylabel(r'$\bar X_n$')
plt.xlabel(r'n')
# Out:
# Text(0.5, 0, 'n')

# %% [markdown]
# As we can see here, the dispersion of $\bar X_n$ decreases with the increase of $n$. For $n = 250$ all points are localized in the small interval in contrast to $\bar X_n$ points related to $n = 8$, which are more spread.

# %% [markdown]
# ## b)

# %% [markdown]
# As $Var(\bar X_n) = \frac{\sigma ^ 2}{n}$ and $\sigma = \lambda = 1$,
#
# $Var(\bar X_n) = \frac{1}{n}$

# %%
plt.title('vars')
plt.plot(1/np.array(N), var, '.')
plt.plot([0, 1], [0, 1], '--')
plt.ylabel(r'$Var(\bar X_n)$')
plt.xlabel(r'$\frac{1}{n}$')
# Out:
# Text(0.5, 0, '$\\frac{1}{n}$')
